# %%
import nltk
import numpy
import string
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
from nltk.corpus import PlaintextCorpusReader
from nltk.text import Text
import re

# %%
file = open('nls-text-indiaPapers/74457530.txt','r')
raw_data = file.read()
tokens = word_tokenize(raw_data)
lower_tokens = [word.lower() for word in tokens]

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
women_strings = [w for w in lower_tokens if re.search('^wom[ae]n$', w)]

# %%
women_strings
# Out:
# ['women',
#  'women',
#  'women',
#  'woman',
#  'woman',
#  'woman',
#  'woman',
#  'woman',
#  'woman',
#  'woman',
#  'woman',
#  'woman',
#  'women',
#  'woman',
#  'women',
#  'women',
#  'woman',
#  'women',
#  'woman',
#  'women',
#  'woman',
#  'woman',
#  'woman',
#  'woman',
#  'women',
#  'women',
#  'women',
#  'women',
#  'women',
#  'woman',
#  'woman',
#  'women',
#  'women',
#  'women',
#  'women',
#  'women',
#  'women',
#  'woman',
#  'woman',
#  'women',
#  'women',
#  'women']

# %%
len(women_strings)
# Out:
# 42

# %% [markdown]
# Regural expressions can be very specific and we will not cover them in detail here but they are very powerful to carry out complex searches, e.g. find all tokens starting with a and are 12 characters long (. means a character). Or find all tokens which are 13 characters long but that do not start with a lower case letter ([^a-z] means not the letters a-z).

# %%
[w for w in lower_tokens if re.search('^a............$', w)]
# Out:
# ['antiscorbutic',
#  'approximately',
#  'approximately',
#  'agriculturist',
#  'ages.-chiefly',
#  'approximately',
#  'accommodation']

# %%
[w for w in lower_tokens if re.search('^[^a-z]............$', w)]
# Out:
# ['24-pergunnahs',
#  '19.-commenced',
#  '24-pergunuahs',
#  '24-pergunnahs',
#  '24-pergunnahs',
#  '1875.-patches']

# %%
men_strings1=[w for w in lower_tokens if re.search('^m[ae]n$', w)]

# %%
men_strings1
# Out:
# ['man',
#  'man',
#  'man',
#  'men',
#  'men',
#  'man',
#  'men',
#  'men',
#  'man',
#  'man',
#  'men',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'men',
#  'man',
#  'men',
#  'men',
#  'men',
#  'man',
#  'men',
#  'man',
#  'man',
#  'man',
#  'men',
#  'man',
#  'man',
#  'men',
#  'men',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'men',
#  'men',
#  'man',
#  'men',
#  'man',
#  'man',
#  'men',
#  'man',
#  'man',
#  'man',
#  'men',
#  'man',
#  'men',
#  'men',
#  'men',
#  'man',
#  'men',
#  'man',
#  'men',
#  'man',
#  'men',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'man',
#  'men',
#  'men']

# %%
men_strings2=[w for w in lower_tokens if re.search('m[ae]n', w)]

# %%
men_strings2
# Out:
# ['ment',
#  'government',
#  'government',
#  'government',
#  'government',
#  'government',
#  'government',
#  'department',
#  'government',
#  'department',
#  'government',
#  'department',
#  'government',
#  'government',
#  'government',
#  'treatment',
#  'improvement',
#  'permanent',
#  'liniment',
#  'treatment',
#  'permanent',
#  'treatment',
#  'treatment',
#  'ment',
#  'mentioned',
#  'treatment',
#  'government',
#  'ment',
#  'department',
#  'government',
#  'mentioned',
#  'maneckji',
#  'many',
#  'fisherman',
#  'oilman',
#  'commencement',
#  'man',
#  'man',
#  'mentioned',
#  'treatment',
#  'improvement',
#  'treatment',
#  'treatment',
#  'treatment',
#  'manner',
#  'improvement',
#  'improvement',
#  'man',
#  'commencing',
#  'manmar',
#  'commencing',
#  'mussalman',
#  'treatment',
#  'government',
#  'herdsmen',
#  'ment',
#  'arrangements',
#  'treatment',
#  'instruments',
#  'mendicants',
#  'men',
#  'regiment',
#  'many',
#  'regiment',
#  'governments',
#  'cantonment',
#  'men',
#  'specimens',
#  'many',
#  'man',
#  'many',
#  'government',
#  'government',
#  'government',
#  'department',
#  'government',
#  'government',
#  'department',
#  'government',
#  'governments',
#  'employment',
#  'statement',
#  'statements',
#  'statements',
#  'statements',
#  'establishment',
#  'government',
#  'many',
#  'statement',
#  'statement',
#  'many',
#  'statement',
#  'many',
#  'many',
#  'amanpur',
#  'statements',
#  'statement',
#  'manglaur',
#  'many',
#  'argument',
#  'commencing',
#  'commence-',
#  'ment',
#  'men',
#  'women',
#  'statement',
#  'development',
#  'above-mentioned',
#  'employment',
#  'employment',
#  'employment',
#  'employment',
#  'fisherman',
#  'boatmen',
#  'women',
#  'washermen',
#  'brahmans',
#  'tinman',
#  'men',
#  'employment',
#  'ment',
#  'mentioned',
#  'employments',
#  'employment',
#  'employments',
#  'employment',
#  'many',
#  'employments',
#  'nourishment',
#  'statement',
#  'ment',
#  'many',
#  'statement',
#  'employment',
#  'employment',
#  'washermen',
#  'ornament-makers',
#  'fireman',
#  'weighman',
#  'fishermen',
#  'employment',
#  'man',
#  'man',
#  'many',
#  'ment',
#  'statements',
#  'statement',
#  'men',
#  'women',
#  'mention',
#  'dhuman',
#  'commenced',
#  'statements',
#  'many',
#  'many',
#  'mankind',
#  'man',
#  'woman',
#  'dhuman',
#  'woman',
#  'mani',
#  'brahman',
#  'man',
#  'woman',
#  'man',
#  'man',
#  'woman',
#  'man',
#  'woman',
#  'woman',
#  'man',
#  'man',
#  'woman',
#  'woman',
#  'man',
#  'man',
#  'human',
#  'above-mentioned',
#  'woman',
#  'statement',
#  'many',
#  'statements',
#  'many',
#  'mention',
#  'man',
#  'establishment',
#  'man',
#  'treatment',
#  'improvement',
#  'mentioned',
#  'government',
#  'men',
#  'women',
#  'employment',
#  'mankind',
#  'man',
#  'woman',
#  'many',
#  'statements-1st',
#  'mankind',
#  'men',
#  'men',
#  'women',
#  'management',
#  'men',
#  'man',
#  'government',
#  'government',
#  'government',
#  'government',
#  'government',
#  'government',
#  'government',
#  'statements',
#  'supplementary',
#  'government',
#  'statement',
#  'establishment',
#  'treatment',
#  'mendicants',
#  'many',
#  'ment',
#  'many',
#  'treatment',
#  'treatment',
#  'arrangement',
#  'permanently',
#  'ailments',
#  'treatment',
#  'department',
#  'treatment',
#  'treatment',
#  'treatment',
#  'government',
#  'department',
#  'government',
#  'many',
#  'establishment',
#  'government',
#  'establishment',
#  'mensem',
#  'mensem',
#  'mensem',
#  'mensem',
#  'improvement',
#  'treatment',
#  'treatments',
#  'statement',
#  'women',
#  'many',
#  'woman',
#  'treatment',
#  'treatment',
#  'many',
#  'abdomen',
#  'ointment',
#  'improvement',
#  'improvement',
#  'abdomen',
#  'treatment',
#  'mussalman',
#  'abdomen',
#  'improvement',
#  'improvement',
#  'many',
#  'abdomen',
#  'many',
#  'ointment',
#  'many',
#  'improvement',
#  'improvement',
#  'abdomen',
#  'improvement',
#  'ointment',
#  'ointment',
#  'many',
#  'abdomen',
#  'many',
#  'many',
#  'ointment',
#  'mussulman',
#  'abdomen',
#  'many',
#  'many',
#  'many',
#  'ointment',
#  'many',
#  'abdomen',
#  'improvement',
#  'commenced',
#  'abdomen',
#  'many',
#  'improvement',
#  'many',
#  'improvement',
#  'mandera',
#  'many',
#  'department',
#  'department',
#  'manbhum',
#  'government',
#  'department',
#  'government',
#  'many',
#  'lamentably',
#  'ment',
#  'department',
#  'department',
#  'department',
#  'government',
#  'department',
#  'department',
#  'department',
#  'manners',
#  'manner',
#  'moment',
#  'treatment',
#  'manbhum',
#  'commendation',
#  'department',
#  'manook',
#  'manook',
#  'many',
#  'mussulmans',
#  'many',
#  'manbhum',
#  'department',
#  'manbhum',
#  'men',
#  'women',
#  'immensely',
#  'manbhum',
#  'treatment',
#  'statement',
#  'manbhum',
#  'many',
#  'man',
#  'manner',
#  'treatment',
#  'treatment',
#  'man',
#  'mussalman',
#  'treatment',
#  'treatment',
#  'improvement',
#  'treatment',
#  'improvement',
#  'government',
#  'many',
#  'detriment',
#  'treatment',
#  'improvement',
#  'woman',
#  'statement',
#  'statement',
#  'manner',
#  'department',
#  'many',
#  'demands',
#  'government',
#  'government',
#  'department',
#  'department',
#  'many',
#  'mentioned',
#  'mention',
#  'treatment',
#  'commencement',
#  'many',
#  'many',
#  'statement',
#  'mussulmans',
#  'mussulman',
#  'mussulmans',
#  'mussulmans',
#  'statement',
#  'many',
#  'acquirement',
#  'mention',
#  'man',
#  'many',
#  'statement',
#  'mussulmans',
#  'mancoor',
#  'commences',
#  'ment',
#  'commencing',
#  'commencement',
#  'impairment',
#  'mentioned',
#  'commences',
#  'manifestation',
#  'manner',
#  'commences',
#  'pigment',
#  'commences',
#  'commences',
#  'commences',
#  'commenced',
#  'commence',
#  'manifestations',
#  'development',
#  'men',
#  'women',
#  'mention',
#  'man',
#  'man',
#  'men',
#  'ment',
#  'permanently',
#  'ment',
#  'treatment',
#  'treatment',
#  'manner',
#  'treatment',
#  'improvements',
#  'mention',
#  'treatment',
#  'milkmen',
#  'washermen',
#  'mention',
#  'many',
#  'treatment',
#  'men',
#  'treatment',
#  'treatment',
#  'milkmen',
#  'washermen',
#  'milkman',
#  'man',
#  'washerwoman',
#  'ailment',
#  'milkman',
#  'development',
#  'treatment',
#  'treatment',
#  'ment',
#  'many',
#  'manoolla',
#  'treatment',
#  'inclements',
#  'woman',
#  'mussulmans',
#  'statements',
#  'treatment.-dr.',
#  'treatment',
#  'treatment',
#  'treatment',
#  'statement',
#  'statement',
#  'treatment',
#  'treatment',
#  'improvement',
#  'treatment',
#  'government',
#  'man',
#  'man',
#  'commenced',
#  'mussulman',
#  'menced',
#  'man',
#  'loathsomeness',
#  'man',
#  'improvement',
#  'man',
#  'government',
#  'lamentably',
#  'concealment',
#  'treatment',
#  'men',
#  'woman',
#  'woman',
#  'woman',
#  'commenced',
#  'manifestation',
#  'cartman',
#  'milkman',
#  'development',
#  'men',
#  'man',
#  'medicaments.-both',
#  'many',
#  'human',
#  'medicaments.-every',
#  'medicaments.-none',
#  'medicaments.-none',
#  'medicaments.-from',
#  'medicaments.-none',
#  'medicaments.-took',
#  'medicaments.-none',
#  'medicaments.-ditto',
#  'medicaments-none',
#  'medicaments.-bleeding',
#  'departmental',
#  'government',
#  'government',
#  'women',
#  'women',
#  'women',
#  'women',
#  'many',
#  'statement',
#  'manner',
#  'manner',
#  'fishermen',
#  'fishermen',
#  'men',
#  'manner',
#  'mussulmans',
#  'fishermen',
#  'boatmen',
#  'women',
#  'woman',
#  'woman',
#  'women',
#  'ment',
#  'statement',
#  'many',
#  'treatment',
#  'treatment',
#  'ernment',
#  'supplementary',
#  'statements',
#  'many',
#  'many',
#  'treatment',
#  'man',
#  'ment',
#  'amanatgunge',
#  'ment',
#  'many',
#  'department',
#  'treatment',
#  'statement',
#  'statement',
#  'treatment',
#  'treatment',
#  'man',
#  'mymensingh',
#  'mymensingh',
#  'manikgunge',
#  'abdomen',
#  'enlargement',
#  'manikgunge',
#  'manikgunge',
#  'manikgunge',
#  'manikgunge',
#  'manikgunge',
#  'many',
#  'many',
#  'mentioned',
#  'many',
#  'department',
#  'many',
#  'many',
#  'department',
#  'treatment',
#  'treatment',
#  'treatment',
#  'many',
#  'men',
#  'man',
#  'man',
#  'man',
#  'treatment',
#  'improvement',
#  'development',
#  'detriment',
#  'treatment',
#  'men',
#  'women',
#  'fishermen',
#  'ment',
#  'treatment.-one',
#  'treatment',
#  'treatment',
#  'enlargement',
#  'man',
#  'many',
#  'treatment',
#  'manifest',
#  'many',
#  'treatment',
#  'gentleman',
#  'judgment',
#  'commenced',
#  'treatment.-september',
#  'commence',
#  'treatment.-september',
#  'commenced',
#  'rahaman',
#  'commenced',
#  'commencement',
#  'menced',
#  'treatment',
#  'treatment',
#  'commence',
#  'ointment',
#  'fisherman',
#  'integument',
#  'treatment.-october.-commenced',
#  'abdomen',
#  'commenced',
#  'treatment.-28.-commenced',
#  'treatment',
#  'abdomen',
#  'mussalman',
#  'commenced',
#  'many',
#  'treatment.-october.-commenced',
#  'commenced',
#  'commenced',
#  'treatment.-october',
#  '19.-commenced',
#  'improvement',
#  'mussalmans',
#  'mussalmans',
#  'department',
#  'government',
#  'commented',
#  'mymensing',
#  'many',
#  'comment',
#  'demand',
#  'women',
#  'understatement',
#  'overstatement',
#  'mentioned',
#  'mentions',
#  'mentioned',
#  'immense',
#  'manifestation',
#  'statement',
#  'men',
#  'statement',
#  'manner',
#  'manifestation',
#  'many',
#  'manifestation',
#  'ment',
#  'men',
#  'women',
#  'mentioned',
#  'treatment',
#  'treatment',
#  'treatment',
#  'permanent',
#  'government',
#  'instalment',
#  'department',
#  'comment',
#  'department',
#  'department',
#  'mentioned',
#  'mentioned',
#  'men',
#  'women',
#  'ment',
#  'statement',
#  'statement',
#  'ernment',
#  'government',
#  'mentioned',
#  'demand',
#  'many',
#  'many',
#  'many',
#  'man',
#  'treatment',
#  'men',
#  'many',
#  'dimensions',
#  'arrangement',
#  'man',
#  'treatment',
#  'mussalman',
#  'many',
#  'improvement',
#  'department',
#  'department',
#  'treatment',
#  'treatment',
#  'development',
#  'men',
#  'women',
#  'government',
#  'department',
#  'many',
#  'moment',
#  'mussalmans',
#  'treatment',
#  'treatment',
#  'imprisonment',
#  'treatment',
#  'treatment',
#  'man',
#  'department',
#  'government',
#  'government',
#  'department',
#  'endorsement',
#  'government',
#  'government',
#  'many',
#  'statement',
#  'many',
#  'concealment',
#  'many',
#  'mentions',
#  'mention',
#  'mentions',
#  'many',
#  'men',
#  'command',
#  'mention',
#  'many',
#  'employments',
#  'fellow-townsmen',
#  'treatment',
#  'treatment',
#  'treatment',
#  'commenced',
#  'commenced',
#  'commenced',
#  'statements',
#  'statement',
#  'mentioned',
#  'statement',
#  'statement',
#  'statement',
#  'many',
#  'many',
#  'many',
#  'many',
#  'statement',
#  'treatment',
#  'treatment',
#  'treatment',
#  'treatment',
#  'ment',
#  'treatment.-has',
#  'treatment',
#  'treatment',
#  'treatment.-has',
#  'treatment',
#  'mussulman',
#  'treatment.-dark',
#  'treatment',
#  'treatment',
#  'treatment.-no',
#  'pigment',
#  'treatment',
#  'treatment.-skin',
#  'treatment',
#  'treatment.-skin',
#  'treatment',
#  'statement',
#  'treatment',
#  'mussulman',
#  'mussalman',
#  'mussalman',
#  'statement',
#  'treatment',
#  'treatment',
#  'arrangements',
#  'statement',
#  'statement',
#  'treatment',
#  'mussulman',
#  'amaneegunge',
#  'treatment',
#  'ment',
#  'treatment',
#  'treatment',
#  'treatment',
#  'improvement',
#  'treatment',
#  'employment',
#  'development',
#  'commence',
#  'enjoyment',
#  'ailments',
#  'woman',
#  'manner',
#  'treatment',
#  'improvement',
#  'mussulman',
#  'man',
#  'commenced',
#  'mentioned',
#  'treatment',
#  'man',
#  'development',
#  'treatment',
#  'commenced',
#  'albumen',
#  'treatment',
#  'treatment',
#  'man',
#  'man',
#  'treatment',
#  'integumental',
#  'integument',
#  'treatment',
#  'man',
#  'man',
#  'treatment',
#  'treatment',
#  'treatment',
#  'menced',
#  'ment',
#  'treatment',
#  'statement',
#  'many',
#  'informant',
#  'many',
#  'remaning',
#  'development',
#  'government',
#  'pigment',
#  'treatment',
#  'many',
#  'mussalmans',
#  'settlement',
#  'manner',
#  'commenced',
#  'mentioned',
#  'mussulmani',
#  'manifested',
#  'treatment',
#  'employment',
#  'government',
#  'department',
#  'ment',
#  'department',
#  'government',
#  'department',
#  'endorsement',
#  'many',
#  'statements',
#  'mandla',
#  'treatment',
#  'treatment',
#  'treatment',
#  'manufacturing',
#  'mendicants',
#  'menial',
#  'menial',
#  'manifests',
#  'many',
#  'statements',
#  'many',
#  'many',
#  'treatment',
#  'treatment',
#  'development',
#  'mentioned',
#  'confinement',
#  'government',
#  'government',
#  'department',
#  'endorsement',
#  'department',
#  'government',
#  'department',
#  'government',
#  'treatment',
#  'treatment',
#  'statement',
#  'treatment',
#  'many',
#  'government',
#  'man',
#  'woman',
#  'mentioned',
#  'statements',
#  'burman',
#  'fellowmen',
#  'treatment',
#  'government',
#  'department',
#  'treatment',
#  'treatment',
#  'treatment',
#  'treatment',
#  'experiments',
#  'treatment',
#  'treatment',
#  'regiment',
#  'treatment',
#  'excrementi-',
#  'treatment',
#  'treatment',
#  'treatment',
#  'improvement',
#  'treatment',
#  'amenable',
#  'treatment',
#  'treatment',
#  'treatment',
#  'treatment',
#  'improvement',
#  'treatment',
#  'treatment',
#  'treatment',
#  'manifested',
#  'treatment',
#  'experiment',
#  'imprisonment',
#  'mendicants',
#  'treatment',
#  'employment',
#  'improvement',
#  'government',
#  'government',
#  'department',
#  'endorsement',
#  'accompaniments',
#  'endorsement',
#  'government',
#  'treatment',
#  'man',
#  'treatment',
#  'treatment',
#  'gentlemen',
#  'endorsement',
#  'government',
#  'government',
#  'commended',
#  'treatment',
#  'endorsement',
#  'arrangement',
#  'treatment',
#  'government',
#  'department',
#  'many',
#  'treatment',
#  'recommended',
#  'recommend',
#  'requirements',
#  'treatment',
#  'treatment',
#  'endorsement',
#  'arrangement',
#  'treatment',
#  'government',
#  'government',
#  'government',
#  'statements',
#  'many',
#  'manifest',
#  'many',
#  'mussalman',
#  'employment',
#  'bankments',
#  'women',
#  'treatment',
#  'confinement',
#  'treatment',
#  'treatment',
#  'many',
#  'treatment',
#  'mentioned',
#  'development',
#  'men',
#  'women',
#  'judgment',
#  'mentioned',
#  'mussalmans',
#  'recommended',
#  'treatment',
#  'ment',
#  'statements',
#  'menial',
#  'mussalmans',
#  'men',
#  'women',
#  'treatment',
#  'many',
#  'employment',
#  'many',
#  'man-']
